# %%
cd'/content/drive/MyDrive/Convo'
# Out:
# /content/drive/MyDrive/Convo

# %%
ls
# Out:
# Pandas.ipynb  survey_results_public.csv  survey_results_schema.csv

# %%
print("23-6-25")
# Out:
# 23-6-25

# %%
import pandas as pd

data = {
  "col1": [50, 40, 30],
  "col2": [300, 1112, 42],
  "col3": ['abc', 'asf', 'asd'],
  "col3": ['abc12', 'asf', 'asd']
}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    col1  col2   col3
# 0    50   300  abc12
# 1    40  1112    asf
# 2    30    42    asd

# %% [markdown]
# ### **Sum**

# %% [markdown]
# har column ka sum nikla lar deta (column name bhi print krta and us ka sath uska sum value(negatives hon to wo minus hojatay)). or agr strings hon to wo sari rows ke vales concatenate hojaeingi

# %%
sum = df.agg(["sum"])
print(sum)
# Out:
#      col1  col2         col3
# sum   120  1454  abc12asfasd

# %%
type(sum)
# Out:
# pandas.core.frame.DataFrame

# %%
#sum[i] will not work

single_col = (df['col2'].agg('sum'))

# %%
print(single_col)
# Out:
# 1454

# %%
type(single_col)
# Out:
# numpy.int64

# %% [markdown]
# "Youtube - https://www.youtube.com/watch?v=ZyhVh-qRZPA&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS "

# %%
df = pd.read_csv('/content/drive/MyDrive/Convo/survey_results_public.csv')

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %%
df.shape
# Out:
# (65437, 114)

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Data columns (total 114 columns):
#  #    Column                          Non-Null Count  Dtype
# ---   ------                          --------------  -----
#  0    ResponseId                      65437 non-null  int64
#  1    MainBranch                      65437 non-null  object
#  2    Age                             65437 non-null  object
#  3    Employment                      65437 non-null  object
#  4    RemoteWork                      54806 non-null  object
#  5    Check                           65437 non-null  object
#  6    CodingActivities                54466 non-null  object
#  7    EdLevel                         60784 non-null  object
#  8    LearnCode                       60488 non-null  object
#  9    LearnCodeOnline                 49237 non-null  object
#  10   TechDoc                         40897 non-null  object
#  11   YearsCode                       59869 non-null  object
# ...

# %%
scheme_df = pd.read_csv('/content/drive/MyDrive/Convo/survey_results_schema.csv')

# %%
scheme_df.head(10)
# Out:
#       qid             qname  \
# 0    QID2        MainBranch
# 1  QID127               Age
# 2  QID296        Employment
# 3  QID308        RemoteWork
# 4  QID341             Check
# 5  QID297  CodingActivities
# 6   QID25           EdLevel
# 7  QID276         LearnCode
# 8  QID281   LearnCodeOnline
# 9  QID331           TechDoc
#
#                                             question force_resp type selector
# 0  Which of the following options best describes ...       True   MC     SAVR
# 1                                 What is your age?*       True   MC     SAVR
# 2  Which of the following best describes your cur...       True   MC     MAVR
# 3  Which best describes your current work situation?      False   MC     SAVR
# 4  Just checking to make sure you are paying atte...       True   MC     SAVR
# 5  Which of the following best describes the code...      False   MC     MAVR
# 6  Which of the following best describes the high...       True   MC     SAVR
# ...

# %%
scheme_df.tail(10)
# Out:
#        qid            qname  \
# 77  QID290      Frequency_3
# 78  QID337   JobSatPoints_1
# 79  QID337   JobSatPoints_4
# 80  QID337   JobSatPoints_5
# 81  QID337   JobSatPoints_6
# 82  QID337   JobSatPoints_7
# 83  QID337   JobSatPoints_8
# 84  QID337   JobSatPoints_9
# 85  QID337  JobSatPoints_10
# 86  QID337  JobSatPoints_11
#
#                                              question force_resp type selector
# 77  Encountering knowledge silos (where one indivi...        NaN   MC     MAVR
# 78                       Driving strategy for my team        NaN   MC     MAVR
# 79                        Contributing to open source        NaN   MC     MAVR
# 80                     Securing data and environments        NaN   MC     MAVR
# 81  Improving quality of code and developer enviro...        NaN   MC     MAVR
# 82  Learning and using new technology, including p...        NaN   MC     MAVR
# 83  Designing and building environments, databases...        NaN   MC     MAVR
# ...

# %%
#column getting ka liye sinple df['name_of_col'] lkhna , but multiple bhi access ho saktay we have to send a list in side i.e. df[['col1' , 'col2']]
df['Age']
# Out:
# 0        Under 18 years old
# 1           35-44 years old
# 2           45-54 years old
# 3           18-24 years old
# 4           18-24 years old
#                 ...
# 65432       18-24 years old
# 65433       25-34 years old
# 65434       25-34 years old
# 65435       18-24 years old
# 65436       18-24 years old
# Name: Age, Length: 65437, dtype: object

# %%
# counts jo ha wo us column ka andr values ka count btata
df['Age'].value_counts()
# Out:
# Age
# 25-34 years old       23911
# 35-44 years old       14942
# 18-24 years old       14098
# 45-54 years old        6249
# 55-64 years old        2575
# Under 18 years old     2568
# 65 years or older       772
# Prefer not to say       322
# Name: count, dtype: int64

# %%
#multiple
df[['Age' , 'Employment' ]]
# Out:
#                       Age           Employment
# 0      Under 18 years old  Employed, full-time
# 1         35-44 years old  Employed, full-time
# 2         45-54 years old  Employed, full-time
# 3         18-24 years old   Student, full-time
# 4         18-24 years old   Student, full-time
# ...                   ...                  ...
# 65432     18-24 years old  Employed, full-time
# 65433     25-34 years old  Employed, full-time
# 65434     25-34 years old  Employed, full-time
# 65435     18-24 years old  Employed, full-time
# 65436     18-24 years old   Student, full-time
#
# [65437 rows x 2 columns]

# %%
#rows get krnay ka liye na loc and iloc (loc with integer) use krtay - Wohi agr sible int deinga to aik row return honi warna multiple rows(tripped dataframe)
df.iloc[2]
# Out:
# ResponseId                                          3
# MainBranch             I am a developer by profession
# Age                                   45-54 years old
# Employment                        Employed, full-time
# RemoteWork                                     Remote
#                                     ...
# JobSatPoints_11                                   NaN
# SurveyLength                    Appropriate in length
# SurveyEase                                       Easy
# ConvertedCompYearly                               NaN
# JobSat                                            NaN
# Name: 2, Length: 114, dtype: object

# %%
#multiple
df.iloc[[0,1,2]]
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
#
#                                            EdLevel  \
# 0                        Primary/elementary school
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                            LearnCode  \
# ...

# %%
#comma sa pehlay we have rows and comma ka baad we can give column names as well
df.iloc[[1,2,3,] , [0,1,2]]
# Out:
#    ResponseId                      MainBranch              Age
# 1           2  I am a developer by profession  35-44 years old
# 2           3  I am a developer by profession  45-54 years old
# 3           4           I am learning to code  18-24 years old

# %%
# loc mein indexes nhi chalay ge columnm pa
# slicing also works but list nhi ha to wo bracket nhi ayeingay
df.loc[[0,1,2] , ['Age']]
# Out:
#                   Age
# 0  Under 18 years old
# 1     35-44 years old
# 2     45-54 years old

# %%
df.loc[0:4 , 'Age': 'EdLevel']
# Out:
#                   Age           Employment RemoteWork   Check  \
# 0  Under 18 years old  Employed, full-time     Remote  Apples
# 1     35-44 years old  Employed, full-time     Remote  Apples
# 2     45-54 years old  Employed, full-time     Remote  Apples
# 3     18-24 years old   Student, full-time        NaN  Apples
# 4     18-24 years old   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# ...

# %%
 # we can also have our desried column as the index, normally wo usko set nhi ktay ga but we can do it zabardastily (like keh email aik unique udentifier ha to wo use krna could be helpful)
df.set_index('Country' , inplace = True)

# %%
df
# Out:
#                                                     ResponseId  \
# Country
# United States of America                                     1
# United Kingdom of Great Britain and Northern Ir...           2
# United Kingdom of Great Britain and Northern Ir...           3
# Canada                                                       4
# Norway                                                       5
# ...                                                        ...
# NaN                                                      65433
# NaN                                                      65434
# NaN                                                      65435
# Germany                                                  65436
# NaN                                                      65437
#
#                                                                         MainBranch  \
# Country
# United States of America                            I am a developer by profession
# ...

# %%
df.loc['Germany']
# Out:
#          ResponseId                                         MainBranch  \
# Country
# Germany          19                     I am a developer by profession
# Germany          21  I am not primarily a developer, but I write co...
# Germany          22                     I am a developer by profession
# Germany          49                     I am a developer by profession
# Germany          50                     I am a developer by profession
# ...             ...                                                ...
# Germany       65164                     I am a developer by profession
# Germany       65182                     I am a developer by profession
# Germany       65335                     I am a developer by profession
# Germany       65372  I am not primarily a developer, but I write co...
# Germany       65436                     I am a developer by profession
#
#                        Age                                         Employment  \
# Country
# ...

# %%
df.loc['Germany' , 'Age']
# Out:
# Country
# Germany      25-34 years old
# Germany      25-34 years old
# Germany      35-44 years old
# Germany    65 years or older
# Germany      25-34 years old
#                  ...
# Germany      18-24 years old
# Germany      25-34 years old
# Germany      18-24 years old
# Germany      25-34 years old
# Germany      18-24 years old
# Name: Age, Length: 4947, dtype: object

# %%
# this wont work kion keh we have replacd the default index with country
# df.loc[0]

# %%
# iloc will keep on working , ye bas index ko replace kray ga and baqi almost sara wese he rahay ga
df.iloc[[0,1,3,5] , [0,2,4,5]]
# Out:
#                                                     ResponseId  \
# Country
# United States of America                                     1
# United Kingdom of Great Britain and Northern Ir...           2
# Canada                                                       4
# United States of America                                     6
#
#                                                                    Age  \
# Country
# United States of America                            Under 18 years old
# United Kingdom of Great Britain and Northern Ir...     35-44 years old
# Canada                                                 18-24 years old
# United States of America                            Under 18 years old
#
#                                                    RemoteWork   Check
# Country
# United States of America                               Remote  Apples
# United Kingdom of Great Britain and Northern Ir...     Remote  Apples
# ...

# %%
df.reset_index(inplace = True)

# %%
df.head()
# Out:
#                                              Country  ResponseId  \
# 0                           United States of America           1
# 1  United Kingdom of Great Britain and Northern I...           2
# 2  United Kingdom of Great Britain and Northern I...           3
# 3                                             Canada           4
# 4                                             Norway           5
#
#                        MainBranch                 Age           Employment  \
# 0  I am a developer by profession  Under 18 years old  Employed, full-time
# 1  I am a developer by profession     35-44 years old  Employed, full-time
# 2  I am a developer by profession     45-54 years old  Employed, full-time
# 3           I am learning to code     18-24 years old   Student, full-time
# 4  I am a developer by profession     18-24 years old   Student, full-time
#
#   RemoteWork   Check                                   CodingActivities  \
# ...

# %%
scheme_df = pd.read_csv('/content/drive/MyDrive/Convo/survey_results_schema.csv' , index_col='qname')

# %%
scheme_df
# Out:
#                     qid                                           question  \
# qname
# MainBranch         QID2  Which of the following options best describes ...
# Age              QID127                                 What is your age?*
# Employment       QID296  Which of the following best describes your cur...
# RemoteWork       QID308  Which best describes your current work situation?
# Check            QID341  Just checking to make sure you are paying atte...
# ...                 ...                                                ...
# JobSatPoints_7   QID337  Learning and using new technology, including p...
# JobSatPoints_8   QID337  Designing and building environments, databases...
# JobSatPoints_9   QID337  Being a power user of a tool, developer langua...
# JobSatPoints_10  QID337       Working with new and/or top-quality hardware
# JobSatPoints_11  QID337  A well-staffed/sourced internal network that m...
#
#                 force_resp type selector
# qname
# ...

# %%
scheme_df.loc['Age']
# Out:
# qid                       QID127
# question      What is your age?*
# force_resp                  True
# type                          MC
# selector                    SAVR
# Name: Age, dtype: object

# %%
scheme_df.loc['Check' , 'question']
# Out:
# 'Just checking to make sure you are paying attention to the survey questions. Select ‘Apples’ from the list and you can get back to the survey.*<br><br>'

# %%
scheme_df.sort_index()
# Out:
#                  qid                                           question  \
# qname
# AIAcc         QID316  How much do you trust the accuracy of the outp...
# AIBen         QID324  For the AI tools you use as part of your devel...
# AIChallenges  QID346  What are the challenges to your company/whole ...
# AIComplex     QID343  How well do the AI tools you use in your devel...
# AIEthics      QID339  Which AI ethical responsibilities are most imp...
# ...              ...                                                ...
# ToolsTech     QID275  Which <b>developer </b><strong>tools for compi...
# Webframe      QID264  Which <b>web frameworks and web technologies</...
# WorkExp       QID288  How many years of working experience do you have?
# YearsCode      QID32  Including any education, how many years have y...
# YearsCodePro   QID34  NOT including education, how many years have y...
#
#              force_resp    type selector
# qname
# AIAcc             False      MC     SAVR
# ...

# %%
#Filter bhi usefull hein kaafi zayada,

filt = (df['Age'] == '25-34 years old')

# %%
df[filt]
# Out:
#                                                  Country  ResponseId  \
# 14                                              Bulgaria          15
# 18                                               Germany          19
# 20                                               Germany          21
# 27                                               Ukraine          28
# 28     United Kingdom of Great Britain and Northern I...          29
# ...                                                  ...         ...
# 65424                                                NaN       65425
# 65427                                                NaN       65428
# 65428                                              India       65429
# 65433                                                NaN       65434
# 65434                                                NaN       65435
#
#                                               MainBranch              Age  \
# ...

# %%
df.loc[filt]
# Out:
#                                                  Country  ResponseId  \
# 14                                              Bulgaria          15
# 18                                               Germany          19
# 20                                               Germany          21
# 27                                               Ukraine          28
# 28     United Kingdom of Great Britain and Northern I...          29
# ...                                                  ...         ...
# 65424                                                NaN       65425
# 65427                                                NaN       65428
# 65428                                              India       65429
# 65433                                                NaN       65434
# 65434                                                NaN       65435
#
#                                               MainBranch              Age  \
# ...

# %%
df.loc[filt , 'Country']
# Out:
# 14                                                Bulgaria
# 18                                                 Germany
# 20                                                 Germany
# 27                                                 Ukraine
# 28       United Kingdom of Great Britain and Northern I...
#                                ...
# 65424                                                  NaN
# 65427                                                  NaN
# 65428                                                India
# 65433                                                  NaN
# 65434                                                  NaN
# Name: Country, Length: 23911, dtype: object

# %%
filt = (df['Age'] == '25-34 years old') & (df['Country'] == 'Germany')

# %%
df.loc[filt]
# Out:
#        Country  ResponseId                                         MainBranch  \
# 18     Germany          19                     I am a developer by profession
# 20     Germany          21  I am not primarily a developer, but I write co...
# 49     Germany          50                     I am a developer by profession
# 87     Germany          88                     I am a developer by profession
# 123    Germany         124                     I am a developer by profession
# ...        ...         ...                                                ...
# 64886  Germany       64887  I am not primarily a developer, but I write co...
# 64902  Germany       64903  I am not primarily a developer, but I write co...
# 64904  Germany       64905                     I am a developer by profession
# 65181  Germany       65182                     I am a developer by profession
# 65371  Germany       65372  I am not primarily a developer, but I write co...
#
# ...

# %%
# ye ab filer bhi lag raha and then uske upar column wo specific jo humein chahiye ( col mein slice and int nhi ho sakta kion keh LOC use kr rahay , but can give multiple)
df.loc[filt , 'MainBranch']
# Out:
# 18                          I am a developer by profession
# 20       I am not primarily a developer, but I write co...
# 49                          I am a developer by profession
# 87                          I am a developer by profession
# 123                         I am a developer by profession
#                                ...
# 64886    I am not primarily a developer, but I write co...
# 64902    I am not primarily a developer, but I write co...
# 64904                       I am a developer by profession
# 65181                       I am a developer by profession
# 65371    I am not primarily a developer, but I write co...
# Name: MainBranch, Length: 1847, dtype: object

# %%
#negating the filter
df.loc[~filt , 'MainBranch']
# Out:
# 0        I am a developer by profession
# 1        I am a developer by profession
# 2        I am a developer by profession
# 3                 I am learning to code
# 4        I am a developer by profession
#                       ...
# 65432    I am a developer by profession
# 65433    I am a developer by profession
# 65434    I am a developer by profession
# 65435    I am a developer by profession
# 65436       I code primarily as a hobby
# Name: MainBranch, Length: 63590, dtype: object

# %%
countries = ['United Stated' , ' Inida' , 'Germany']

# %%
filt = df['Country'].isin(countries)

# %%
df.loc[filt]
# Out:
#        Country  ResponseId                                         MainBranch  \
# 18     Germany          19                     I am a developer by profession
# 20     Germany          21  I am not primarily a developer, but I write co...
# 21     Germany          22                     I am a developer by profession
# 48     Germany          49                     I am a developer by profession
# 49     Germany          50                     I am a developer by profession
# ...        ...         ...                                                ...
# 65163  Germany       65164                     I am a developer by profession
# 65181  Germany       65182                     I am a developer by profession
# 65334  Germany       65335                     I am a developer by profession
# 65371  Germany       65372  I am not primarily a developer, but I write co...
# 65435  Germany       65436                     I am a developer by profession
#
# ...

# %%
filt
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 65432    False
# 65433    False
# 65434    False
# 65435     True
# 65436    False
# Name: Country, Length: 65437, dtype: bool

# %%
df.columns
# Out:
# Index(['Country', 'ResponseId', 'MainBranch', 'Age', 'Employment',
#        'RemoteWork', 'Check', 'CodingActivities', 'EdLevel', 'LearnCode',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %%
df.columns = [x.upper() for x in df.columns]

# %%
df.columns
# Out:
# Index(['COUNTRY', 'RESPONSEID', 'MAINBRANCH', 'AGE', 'EMPLOYMENT',
#        'REMOTEWORK', 'CHECK', 'CODINGACTIVITIES', 'EDLEVEL', 'LEARNCODE',
#        ...
#        'JOBSATPOINTS_6', 'JOBSATPOINTS_7', 'JOBSATPOINTS_8', 'JOBSATPOINTS_9',
#        'JOBSATPOINTS_10', 'JOBSATPOINTS_11', 'SURVEYLENGTH', 'SURVEYEASE',
#        'CONVERTEDCOMPYEARLY', 'JOBSAT'],
#       dtype='object', length=114)

# %%
df.columns = df.columns.str.replace(' ' , '_')

# %%
filt = df['COUNTRY'] == 'Germany'

# %%
df.loc[filt , 'COUNTRY'] = 'deutschland'

# %%
df.loc[filt, 'COUNTRY']
# Out:
# 18       deutschland
# 20       deutschland
# 21       deutschland
# 48       deutschland
# 49       deutschland
#             ...
# 65163    deutschland
# 65181    deutschland
# 65334    deutschland
# 65371    deutschland
# 65435    deutschland
# Name: COUNTRY, Length: 4947, dtype: object

# %%
df['COUNTRY'].str.lower()
# Out:
# 0                                 united states of america
# 1        united kingdom of great britain and northern i...
# 2        united kingdom of great britain and northern i...
# 3                                                   canada
# 4                                                   norway
#                                ...
# 65432                                                  NaN
# 65433                                                  NaN
# 65434                                                  NaN
# 65435                                          deutschland
# 65436                                                  NaN
# Name: COUNTRY, Length: 65437, dtype: object

# %%
df['COUNTRY'] = df['COUNTRY'].str.lower()

# %%
df.head()
# Out:
#                                              COUNTRY  RESPONSEID  \
# 0                           united states of america           1
# 1  united kingdom of great britain and northern i...           2
# 2  united kingdom of great britain and northern i...           3
# 3                                             canada           4
# 4                                             norway           5
#
#                        MAINBRANCH                 AGE           EMPLOYMENT  \
# 0  I am a developer by profession  Under 18 years old  Employed, full-time
# 1  I am a developer by profession     35-44 years old  Employed, full-time
# 2  I am a developer by profession     45-54 years old  Employed, full-time
# 3           I am learning to code     18-24 years old   Student, full-time
# 4  I am a developer by profession     18-24 years old   Student, full-time
#
#   REMOTEWORK   CHECK                                   CODINGACTIVITIES  \
# ...

# %%
df.rename(columns = {'EDLEVEL': 'Education_Level'} , inplace = True)

# %%
df.head()
# Out:
#                                              COUNTRY  RESPONSEID  \
# 0                           united states of america           1
# 1  united kingdom of great britain and northern i...           2
# 2  united kingdom of great britain and northern i...           3
# 3                                             canada           4
# 4                                             norway           5
#
#                        MAINBRANCH                 AGE           EMPLOYMENT  \
# 0  I am a developer by profession  Under 18 years old  Employed, full-time
# 1  I am a developer by profession     35-44 years old  Employed, full-time
# 2  I am a developer by profession     45-54 years old  Employed, full-time
# 3           I am learning to code     18-24 years old   Student, full-time
# 4  I am a developer by profession     18-24 years old   Student, full-time
#
#   REMOTEWORK   CHECK                                   CODINGACTIVITIES  \
# ...

# %%
df['COUNTRY'].replace({'canada': 'CANADA' , 'united states of america': 'USA'}, inplace = True)
# Out:
# /tmp/ipython-input-144-2820876893.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['COUNTRY'].replace({'canada': 'CANADA' , 'united states of america': 'USA'}, inplace = True)

# %%
df.head()
# Out:
#                                              COUNTRY  RESPONSEID  \
# 0                                                USA           1
# 1  united kingdom of great britain and northern i...           2
# 2  united kingdom of great britain and northern i...           3
# 3                                             CANADA           4
# 4                                             norway           5
#
#                        MAINBRANCH                 AGE           EMPLOYMENT  \
# 0  I am a developer by profession  Under 18 years old  Employed, full-time
# 1  I am a developer by profession     35-44 years old  Employed, full-time
# 2  I am a developer by profession     45-54 years old  Employed, full-time
# 3           I am learning to code     18-24 years old   Student, full-time
# 4  I am a developer by profession     18-24 years old   Student, full-time
#
#   REMOTEWORK   CHECK                                   CODINGACTIVITIES  \
# ...

# %%
df.iloc[0]
# Out:
# COUNTRY                                           USA
# RESPONSEID                                          1
# MAINBRANCH             I am a developer by profession
# AGE                                Under 18 years old
# EMPLOYMENT                        Employed, full-time
#                                     ...
# JOBSATPOINTS_11                                   NaN
# SURVEYLENGTH                                      NaN
# SURVEYEASE                                        NaN
# CONVERTEDCOMPYEARLY                               NaN
# JOBSAT                                            NaN
# Name: 0, Length: 114, dtype: object

# %%
people = {
    'first' : ['Corey' , 'Jane' , 'John'],
    'last' : ['CSchaffer' , 'Doe' , 'Doe'],
    'email' : ['csg@email.com' , 'aasf@email.com' , 'ddss@email.com']
}
dff = pd.DataFrame(people)

# %%
dff
# Out:
#    first       last           email
# 0  Corey  CSchaffer   csg@email.com
# 1   Jane        Doe  aasf@email.com
# 2   John        Doe  ddss@email.com

# %%
dff['full'] = dff['first'] + ' ' + dff['last']

# %%
dff
# Out:
#    first       last           email             full
# 0  Corey  CSchaffer   csg@email.com  Corey CSchaffer
# 1   Jane        Doe  aasf@email.com         Jane Doe
# 2   John        Doe  ddss@email.com         John Doe

# %%
dff.drop(columns = ['first' , 'last'] , inplace = True)

# %%
dff['full'].str.split(' ')
# Out:
# 0    [Corey, CSchaffer]
# 1           [Jane, Doe]
# 2           [John, Doe]
# Name: full, dtype: object

# %%
dff['full'].str.split(' ' , expand = True)
# Out:
#        0          1
# 0  Corey  CSchaffer
# 1   Jane        Doe
# 2   John        Doe

# %%
dff[['first' , 'last']] = dff['full'].str.split(' ' , expand = True)

# %%
dff
# Out:
#             email             full  first       last
# 0   csg@email.com  Corey CSchaffer  Corey  CSchaffer
# 1  aasf@email.com         Jane Doe   Jane        Doe
# 2  ddss@email.com         John Doe   John        Doe

# %%
people1 = {
    'first' : ['Cori' , 'Jaan'],
    'last' : ['levi' , 'dont' ],
    'email' : ['csasg@email.com' , 'adaasf@email.com']
}
dff1 = pd.DataFrame(people1)

# %%
dff1
# Out:
#   first  last             email
# 0  Cori  levi   csasg@email.com
# 1  Jaan  dont  adaasf@email.com

# %%
dff = pd.concat([dff, dff1] , ignore_index=True)

# %%
dff
# Out:
#               email             full  first       last
# 0     csg@email.com  Corey CSchaffer  Corey  CSchaffer
# 1    aasf@email.com         Jane Doe   Jane        Doe
# 2    ddss@email.com         John Doe   John        Doe
# 3   csasg@email.com              NaN   Cori       levi
# 4  adaasf@email.com              NaN   Jaan       dont

# %%
dff.drop(index=4)
# Out:
#              email             full  first       last
# 0    csg@email.com  Corey CSchaffer  Corey  CSchaffer
# 1   aasf@email.com         Jane Doe   Jane        Doe
# 2   ddss@email.com         John Doe   John        Doe
# 3  csasg@email.com              NaN   Cori       levi

# %%
filt = dff['last'] == 'Doe'
dff[filt].index
# Out:
# Index([1, 2], dtype='int64')

# %%
dff.drop(index = dff[filt].index)
# Out:
#               email             full  first       last
# 0     csg@email.com  Corey CSchaffer  Corey  CSchaffer
# 3   csasg@email.com              NaN   Cori       levi
# 4  adaasf@email.com              NaN   Jaan       dont

# %%
df.sort_values(by=['COUNTRY' , 'CONVERTEDCOMPYEARLY'] , ascending=[True, False] , inplace = True)

# %%
df[['COUNTRY', 'CONVERTEDCOMPYEARLY']].head(50)
# Out:
#       COUNTRY  CONVERTEDCOMPYEARLY
# 21367  CANADA            1562898.0
# 13755  CANADA            1500000.0
# 18038  CANADA            1200000.0
# 36120  CANADA             599716.0
# 19326  CANADA             545197.0
# 21642  CANADA             500000.0
# 1155   CANADA             363465.0
# 2668   CANADA             363465.0
# 870    CANADA             327118.0
# 5695   CANADA             327118.0
# 6303   CANADA             327118.0
# 6803   CANADA             327118.0
# 24722  CANADA             327118.0
# 9288   CANADA             325000.0
# 18739  CANADA             323483.0
# 17201  CANADA             319849.0
# 21886  CANADA             312580.0
# 7860   CANADA             308945.0
# 2708   CANADA             290772.0
# 22686  CANADA             290772.0
# 21557  CANADA             280000.0
# 5001   CANADA             276233.0
# 21903  CANADA             261694.0
# 461    CANADA             254425.0
# 25270  CANADA             254425.0
# 2034   CANADA             247156.0
# ...

# %%
df.nsmallest(10,'CONVERTEDCOMPYEARLY')
# Out:
#            COUNTRY  RESPONSEID  \
# 6963           USA        6964
# 30935          USA       30936
# 22245  afghanistan       22246
# 25200  afghanistan       25201
# 6102      colombia        6103
# 26673  deutschland       26674
# 40353  deutschland       40354
# 3890        france        3891
# 36310        india       36311
# 36370        india       36371
#
#                                               MAINBRANCH                AGE  \
# 6963                      I am a developer by profession    35-44 years old
# 30935  I am not primarily a developer, but I write co...    45-54 years old
# 22245                     I am a developer by profession  65 years or older
# 25200  I am not primarily a developer, but I write co...    18-24 years old
# 6102                      I am a developer by profession    25-34 years old
# 26673                     I am a developer by profession    25-34 years old
# 40353                     I am a developer by profession    25-34 years old
# ...

# %%
df['CONVERTEDCOMPYEARLY'].median()
# Out:
# 65000.0

# %%
df.describe()
# Out:
#          RESPONSEID      COMPTOTAL       WORKEXP  JOBSATPOINTS_1  \
# count  65437.000000   3.374000e+04  29658.000000    29324.000000
# mean   32719.000000  2.963841e+145     11.466957       18.581094
# std    18890.179119  5.444117e+147      9.168709       25.966221
# min        1.000000   0.000000e+00      0.000000        0.000000
# 25%    16360.000000   6.000000e+04      4.000000        0.000000
# 50%    32719.000000   1.100000e+05      9.000000       10.000000
# 75%    49078.000000   2.500000e+05     16.000000       22.000000
# max    65437.000000  1.000000e+150     50.000000      100.000000
#
#        JOBSATPOINTS_4  JOBSATPOINTS_5  JOBSATPOINTS_6  JOBSATPOINTS_7  \
# count    29393.000000    29411.000000    29450.000000     29448.00000
# mean         7.522140       10.060857       24.343232        22.96522
# std         18.422661       21.833836       27.089360        27.01774
# min          0.000000        0.000000        0.000000         0.00000
# ...

# %%
print(df.columns)
# Out:
# Index(['COUNTRY', 'RESPONSEID', 'MAINBRANCH', 'AGE', 'EMPLOYMENT',
#        'REMOTEWORK', 'CHECK', 'CODINGACTIVITIES', 'Education_Level',
#        'LEARNCODE',
#        ...
#        'JOBSATPOINTS_6', 'JOBSATPOINTS_7', 'JOBSATPOINTS_8', 'JOBSATPOINTS_9',
#        'JOBSATPOINTS_10', 'JOBSATPOINTS_11', 'SURVEYLENGTH', 'SURVEYEASE',
#        'CONVERTEDCOMPYEARLY', 'JOBSAT'],
#       dtype='object', length=114)

# %%
df['PLATFORMADMIRED'].value_counts()
# Out:
# PLATFORMADMIRED
# Amazon Web Services (AWS)                                            6240
# Microsoft Azure                                                      3572
# Google Cloud                                                         1692
# Amazon Web Services (AWS);Microsoft Azure                             905
# Amazon Web Services (AWS);Google Cloud                                797
#                                                                      ...
# Cloudflare;Digital Ocean;Hetzner;Vultr                                  1
# Amazon Web Services (AWS);Google Cloud;Netlify;OpenStack                1
# Amazon Web Services (AWS);Heroku;Hetzner;PythonAnywhere                 1
# Cloudflare;Google Cloud;Hetzner;Managed Hosting                         1
# Amazon Web Services (AWS);Cloudflare;Fly.io;Google Cloud;Scaleway       1
# Name: count, Length: 2556, dtype: int64

# %%
df['COUNTRY'].value_counts()
# Out:
# COUNTRY
# USA                                                     11095
# deutschland                                              4947
# india                                                    4231
# united kingdom of great britain and northern ireland     3224
# ukraine                                                  2672
#                                                         ...
# papua new guinea                                            1
# saint kitts and nevis                                       1
# samoa                                                       1
# niger                                                       1
# solomon islands                                             1
# Name: count, Length: 185, dtype: int64

# %%
country_grp = df.groupby(['COUNTRY'])

# %%
country_grp

# %%
country_grp.get_group('USA')
# Out:
# /tmp/ipython-input-174-3152325440.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_grp.get_group('USA')
#       COUNTRY  RESPONSEID                                         MAINBRANCH  \
# 36329     USA       36330                     I am a developer by profession
# 33000     USA       33001                     I am a developer by profession
# 8898      USA        8899                     I am a developer by profession
# 39643     USA       39644                     I am a developer by profession
# 19244     USA       19245                     I am a developer by profession
# ...       ...         ...                                                ...
# 65256     USA       65257                     I am a developer by profession
# 65261     USA       65262                     I am a developer by profession
# ...

# %%
filt = df['COUNTRY'] == 'india'

# %%
df.loc[filt]
# Out:
#       COUNTRY  RESPONSEID                                         MAINBRANCH  \
# 19267   india       19268                     I am a developer by profession
# 34317   india       34318                     I am a developer by profession
# 18602   india       18603                     I am a developer by profession
# 9914    india        9915                     I am a developer by profession
# 6705    india        6706                     I am a developer by profession
# ...       ...         ...                                                ...
# 65339   india       65340  I am not primarily a developer, but I write co...
# 65383   india       65384                              I am learning to code
# 65413   india       65414                              I am learning to code
# 65415   india       65416                        I code primarily as a hobby
# 65428   india       65429                     I am a developer by profession
#
# ...

# %%
df.loc[filt]['PLATFORMADMIRED'].value_counts()
# Out:
# PLATFORMADMIRED
# Amazon Web Services (AWS)                                                                     464
# Microsoft Azure                                                                               159
# Google Cloud                                                                                   97
# Firebase                                                                                       89
# Amazon Web Services (AWS);Microsoft Azure                                                      85
#                                                                                              ...
# Amazon Web Services (AWS);Databricks;Google Cloud;Microsoft Azure;Netlify;OpenStack;Vercel      1
# Amazon Web Services (AWS);Cloudflare;Google Cloud;Netlify;Vercel                                1
# Firebase;Heroku                                                                                 1
# ...

# %%
country_grp['PLATFORMADMIRED'].value_counts(normalize=True).loc['china']
# Out:
# PLATFORMADMIRED
# Alibaba Cloud                               0.188406
# Cloudflare                                  0.096618
# Amazon Web Services (AWS)                   0.082126
# Alibaba Cloud;Cloudflare                    0.033816
# Cloudflare;Vercel                           0.033816
#                                               ...
# OpenStack;VMware                            0.004831
# Oracle Cloud Infrastructure (OCI)           0.004831
# Oracle Cloud Infrastructure (OCI);VMware    0.004831
# Render;Supabase;Vercel                      0.004831
# Supabase;Vercel                             0.004831
# Name: proportion, Length: 75, dtype: float64

# %%
# groupby contries kr ka phr humne salary wala column uthaya and then har country ka median aagaya ha
country_grp['CONVERTEDCOMPYEARLY'].median()
# Out:
# COUNTRY
# CANADA                                   87231.0
# USA                                     143000.0
# afghanistan                               3438.0
# albania                                  35341.0
# algeria                                   7120.0
#                                           ...
# venezuela, bolivarian republic of...     10800.0
# viet nam                                 12288.5
# yemen                                     5333.0
# zambia                                    2280.0
# zimbabwe                                 18000.0
# Name: CONVERTEDCOMPYEARLY, Length: 185, dtype: float64

# %%
# specific country ka bhi check kr saktay
country_grp['CONVERTEDCOMPYEARLY'].median().loc['USA']
# Out:
# np.float64(143000.0)

# %%
# multiple functions use krna ka liye aggeregate use krtay
country_grp['CONVERTEDCOMPYEARLY'].agg(['median' , 'mean'])
# Out:
#                                         median           mean
# COUNTRY
# CANADA                                 87231.0  102348.691160
# USA                                   143000.0  161072.335685
# afghanistan                             3438.0    5057.250000
# albania                                35341.0   39207.545455
# algeria                                 7120.0   91836.700000
# ...                                        ...            ...
# venezuela, bolivarian republic of...   10800.0   20137.371429
# viet nam                               12288.5   18803.281250
# yemen                                   5333.0   16498.400000
# zambia                                  2280.0   17054.400000
# zimbabwe                               18000.0   29681.818182
#
# [185 rows x 2 columns]

# %%
# multiple functions use krna ka liye aggeregate use krtay
country_grp['CONVERTEDCOMPYEARLY'].agg(['median' , 'mean']).loc['USA']
# Out:
# median    143000.000000
# mean      161072.335685
# Name: USA, dtype: float64

# %%
filt = df['COUNTRY'] == 'USA'   # ye to aik data frame bna day ge , filterd data frame on thae filter whch we have
# ye loc ab phr har row get kr raha ha and then hr row pa specific column nikal rahay and then us value pa kuch functions operaete kr rahay
df.loc[filt]['Education_Level'].str.contains("B.A").sum()
# Out:
# np.int64(5561)

# %%
people_BA = country_grp['Education_Level'].apply(lambda x : x.str.contains('B.A').sum())
people_BA
# Out:
# COUNTRY
# CANADA                                   969
# USA                                     5561
# afghanistan                               20
# albania                                   17
# algeria                                   14
#                                         ...
# venezuela, bolivarian republic of...      32
# viet nam                                 181
# yemen                                      6
# zambia                                     8
# zimbabwe                                  13
# Name: Education_Level, Length: 185, dtype: int64

# %%
country_total = df['COUNTRY'].value_counts()
country_total
# Out:
# COUNTRY
# USA                                                     11095
# deutschland                                              4947
# india                                                    4231
# united kingdom of great britain and northern ireland     3224
# ukraine                                                  2672
#                                                         ...
# papua new guinea                                            1
# saint kitts and nevis                                       1
# samoa                                                       1
# niger                                                       1
# solomon islands                                             1
# Name: count, Length: 185, dtype: int64

# %%
combined_df = pd.concat([country_total , people_BA] , axis = 'columns' , sort = False)
combined_df
# Out:
#                                                     count  Education_Level
# COUNTRY
# USA                                                 11095             5561
# deutschland                                          4947             1288
# india                                                4231             2626
# united kingdom of great britain and northern ir...   3224             1354
# ukraine                                              2672              763
# ...                                                   ...              ...
# papua new guinea                                        1                0
# saint kitts and nevis                                   1                0
# samoa                                                   1                0
# niger                                                   1                0
# solomon islands                                         1                0
#
# [185 rows x 2 columns]

# %%
combined_df.rename(columns={ 'count': 'Num_People' , 'Education_Level':'Num_BA' } , inplace=True)

# %%
combined_df
# Out:
#                                                     Num_People  Num_BA
# COUNTRY
# USA                                                      11095    5561
# deutschland                                               4947    1288
# india                                                     4231    2626
# united kingdom of great britain and northern ir...        3224    1354
# ukraine                                                   2672     763
# ...                                                        ...     ...
# papua new guinea                                             1       0
# saint kitts and nevis                                        1       0
# samoa                                                        1       0
# niger                                                        1       0
# solomon islands                                              1       0
#
# [185 rows x 2 columns]

# %%
combined_df['PCT_Done_BA'] =  (combined_df['Num_BA'] / combined_df['Num_People']) * 100

# %%
combined_df
# Out:
#                                                     Num_People  Num_BA  \
# COUNTRY
# USA                                                      11095    5561
# deutschland                                               4947    1288
# india                                                     4231    2626
# united kingdom of great britain and northern ir...        3224    1354
# ukraine                                                   2672     763
# ...                                                        ...     ...
# papua new guinea                                             1       0
# saint kitts and nevis                                        1       0
# samoa                                                        1       0
# niger                                                        1       0
# solomon islands                                              1       0
#
#                                                     PCT_Done_BA
# COUNTRY
# ...

# %%
combined_df.sort_values(by = 'PCT_Done_BA' , ascending=False)
# Out:
#                                        Num_People  Num_BA  PCT_Done_BA
# COUNTRY
# nauru                                           1       1        100.0
# burundi                                         3       3        100.0
# democratic people's republic of korea           2       2        100.0
# dominica                                        1       1        100.0
# guinea                                          1       1        100.0
# ...                                           ...     ...          ...
# papua new guinea                                1       0          0.0
# saint kitts and nevis                           1       0          0.0
# samoa                                           1       0          0.0
# niger                                           1       0          0.0
# solomon islands                                 1       0          0.0
#
# [185 rows x 3 columns]

# %%
combined_df.loc['pakistan']
# Out:
# Num_People     415.000000
# Num_BA         261.000000
# PCT_Done_BA     62.891566
# Name: pakistan, dtype: float64

# %%
import numpy as np

people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'],
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'],
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df= pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
# by default remove all rows which have at least 1 missing column value
df.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
# index ka mtlb rows , how any means keh agar koi bhi missing ha to delete all , AGE 'ALL' use krein to jab tak sari row none nhi hogi tab tak delete nhi kray ga
df.dropna(axis = 'index' , how='any')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis = 'index' , how='all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %% [markdown]
# any basicaly or ha and all jo ha wo and operator

# %%
# agar specific column ke values pa filter lgna to subset use kreingay
df.dropna(axis = 'index' , how='any' , subset = ['email' , 'first'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df['age']
# Out:
# 0         33
# 1         55
# 2         63
# 3         36
# 4       None
# 5       None
# 6    Missing
# Name: age, dtype: object

# %%
df.fillna(0)
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                        0       36
# 4      0        0                        0        0
# 5      0        0      Anonymous@email.com        0
# 6     NA  Missing                       NA  Missing

# %%
df.replace('NA' , np.nan, inplace=True)
df.replace('Missing' , np.nan, inplace=True)

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df['age']  = df['age'].astype(float)

# %%
mean_int = int(df['age'].mean())

# %%
df.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
type(mean_int)
# Out:
# int

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33.0
# 1   Jane      Doe        JaneDoe@email.com  55.0
# 2   John      Doe        JohnDoe@email.com  63.0
# 3  Chris  Schafer                     None  36.0
# 4    NaN      NaN                      NaN   NaN
# 5   None      NaN      Anonymous@email.com   NaN
# 6    NaN      NaN                      NaN   NaN

# %%
na_vals = ['NA' , 'Missing']
df = pd.read_csv('/content/drive/MyDrive/Convo/survey_results_public.csv' , index_col = 'ResponseId' , na_values=na_vals)

# %%
print(df.columns)
# Out:
# Index(['MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'TechDoc',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=113)

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '20', '37', '4', '9', '10', '7', '1', '15', '30', '31', '6',
#        '12', '22', '5', '36', '25', '44', '24', '18', '3', '8',
#        'More than 50 years', '11', '29', '40', '39', '2', '42', '34',
#        '19', '35', '16', '33', '13', '23', '14', '28', '17', '21', '43',
#        '46', '26', '32', '41', '45', '27', '38', '50', '48', '47',
#        'Less than 1 year', '49'], dtype=object)

# %%
df['YearsCode'].replace({'More than 50 years' : 55 , 'Less than 1 year' : 0 }, inplace = True)
# Out:
# /tmp/ipython-input-315-862683871.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['YearsCode'].replace({'More than 50 years' : 55 , 'Less than 1 year' : 0 }, inplace = True)

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '20', '37', '4', '9', '10', '7', '1', '15', '30', '31', '6',
#        '12', '22', '5', '36', '25', '44', '24', '18', '3', '8', 55, '11',
#        '29', '40', '39', '2', '42', '34', '19', '35', '16', '33', '13',
#        '23', '14', '28', '17', '21', '43', '46', '26', '32', '41', '45',
#        '27', '38', '50', '48', '47', 0, '49'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# np.float64(14.214468255691592)

# %%
df['YearsCode'].median()
# Out:
# 11.0

# %%
df['YearsCode'].value_counts().head(5)
# Out:
# YearsCode
# 10.0    4561
# 5.0     3723
# 6.0     3496
# 8.0     3449
# 7.0     3333
# Name: count, dtype: int64

# %%
df['YearsCode'].mode()
# Out:
# 0    10.0
# Name: YearsCode, dtype: float64

# %%
mode_int = int(df['YearsCode'].mode())
# Out:
# /tmp/ipython-input-327-2446425541.py:1: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   mode_int = int(df['YearsCode'].mode())

# %%
type(mode_int)
# Out:
# int

# %%
df['AIToolCurrently Using'].value_counts()
# Out:
# AIToolCurrently Using
# Writing code;Debugging and getting help;Search for answers                                                                                                                                                                                  2023
# Writing code                                                                                                                                                                                                                                1957
# Writing code;Search for answers                                                                                                                                                                                                             1566
# Writing code;Debugging and getting help;Search for answers;Generating content or synthetic data                                                                                                                                              940
# ...
