# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is D88D-1616
#
#  Directory of c:\Users\lenovo\Desktop\CONVO\Pandas\CONVO_Pandas
#
# 24/06/2025  03:54 pm    <DIR>          .
# 24/06/2025  03:54 pm    <DIR>          ..
# 24/06/2025  03:44 pm                64 .gitignore
# 07/08/2024  09:43 am         1,497,191 2024 Developer Survey.pdf
# 24/06/2025  03:51 pm           534,382 Pandas.ipynb
# 24/06/2025  03:54 pm    <DIR>          pandas-master
# 24/06/2025  03:54 pm                 0 pokemon.ipynb
# 19/04/2019  06:38 am            40,832 pokemon_data.csv
# 23/06/2025  01:38 pm        17,703,733 stack-overflow-developer-survey-2024.zip
# 08/08/2024  08:50 am       159,525,875 survey_results_public.csv
# 08/08/2024  08:50 am            12,503 survey_results_schema.csv
#                8 File(s)    179,314,580 bytes
#                3 Dir(s)  22,662,443,008 bytes free

# %%
import pandas as pd
import numpy as np

# %%
poke = pd.read_csv('pokemon_data.csv')

# %%
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df = pd.DataFrame(poke)

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# getting all names which have Grass Type
filt = (df['Type 1'] == 'Grass')
df.loc[filt]['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 48                    Oddish
#                ...
# 718                  Chespin
# 719                Quilladin
# 720               Chesnaught
# 740                   Skiddo
# 741                   Gogoat
# Name: Name, Length: 70, dtype: object

# %%
typ1 = df.groupby(['Type 1'])

# %%
typ1.get_group('Grass')
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# Grouping by the 2 types and then getting specific combined types and applying a filter of being 1st gen

# %%
typ = df.groupby(['Type 1' , 'Type 2'])

# %%
grass_poison = typ.get_group(('Grass' , 'Poison'))

# %%
filt = (df['Generation'] <=1 )

# %%
grass_poison.loc[filt]
# Out:
#      #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49       65
# 1    2                Ivysaur  Grass  Poison  60      62       63       80
# 2    3               Venusaur  Grass  Poison  80      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 48  43                 Oddish  Grass  Poison  45      50       55       75
# 49  44                  Gloom  Grass  Poison  60      65       70       85
# 50  45              Vileplume  Grass  Poison  75      80       85      110
# 75  69             Bellsprout  Grass  Poison  50      75       35       70
# 76  70             Weepinbell  Grass  Poison  65      90       50       85
# 77  71             Victreebel  Grass  Poison  80     105       65      100
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# ...

# %%
filt = df['Legendary'] == True
filt1 = df['Generation'] <= 1
df.loc[filt][filt1]
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19920\3617271282.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.loc[filt][filt1]
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# 164  150  MewtwoMega Mewtwo Y   Psychic       NaN  106     150       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156       95      125     85           1       True
# 157      125       90    100           1       True
# 158      125       85     90           1       True
# 162      154       90    130           1       True
# ...
